# %% [markdown]
# # Example

# %% [markdown]
# Ensure that the Python script, named "twisstntern.py," resides in the current working directory.<br> Additionally, make sure that the csv dataset you intend to use is also present in the same directory.

# %%
# importing the twisstntern library
import twisstntern

# %% [markdown]
# ## User Interface
# - *<u>**Input**</u>* <br>
#  **1. file**: Ensure the input file is a CSV file containing precisely three columns. Assume the first column represents T1, the second represents T2, and the third represents T3. <br>
#  **2. granuality**: Specify the desired granularity by choosing one of the following options: *"coarse"*, *"fine"*, or *"superfine"*. Keep in mind that *"coarse"* corresponds to a granularity of *0.25*, *"fine"* to *0.1*, and *"superfine"* to *0.05*. <br> <br>
# -  *<u>**Output**</u>* : The program will generate a *Results* file comprising the following components:<br>
#  **1. CSV Results Table**: This file will contain the results in CSV format. <br>
#  **2. Basic Asymmetry Plot**: A plot showcasing the basic asymmetry between the left and right halves of the triangle.<br>
#  **3. Ternary Coordinates Plot**: A plot of the data in ternary coordinates. <br>
#  **4. Subtriangles Index Plot**: An index plot with distinct numbers assigned to each subtriangle for clear                                          visualization. These numbers correspond to the indices in the result file. <br>
#  **5. Results Summary Plot**: A plot displaying the results with D_lr results together with significant G-test scoring.

# %%
# example:
# %cd 'gene_flow_sims'
file = "TRUTH_mEDITED.csv"
granuality = "fine"
result=twisstntern.run_analysis(file,granuality)
# Out:
# /home/hlifchit/twisstntern2.0/gene_flow_sims

# %%
import pandas as pd
file_name="A_m0_AGAIN.csv"
data = pd.read_csv(file_name,sep= ';|\t|,', header=None,engine='python')
data=data.iloc[4:]
data=data.iloc[:, [0,1,2]]
data = data.reset_index(drop=True)
data.to_csv("A_m0_AGAIN_EDITED.csv", index=False)

file_name="F_m0.035.csv"
data = pd.read_csv(file_name,sep= ';|\t|,', header=None,engine='python')
data=data.iloc[4:]
data=data.iloc[:, [0,1,2]]
data = data.reset_index(drop=True)
data.to_csv("A_m0EDITED.csv", index=False)

# %%
file = "A_m0_AGAIN_EDITED.csv"
granuality = "fine"
result=twisstntern.run_analysis(file,granuality)
